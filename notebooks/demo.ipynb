# %% [markdown]
# # TRD-UQ demo notebook
#
# This notebook demonstrates how to run the self-contained demo and inspect outputs. It uses the repository scripts `scripts/demo_prepare.py` and `scripts/run_demo.py` and loads `results/demo_outputs.npz`.

# %%
# 1) Prepare demo artifacts (run this once)
# !python scripts/demo_prepare.py

# %%
# 2) Run the demo inference
# !python scripts/run_demo.py

# %%
# 3) Inspect outputs
import numpy as np
data = np.load('results/demo_outputs.npz')
mean = data['mean']
var = data['var']
print('mean shape:', mean.shape)
print('var shape:', var.shape)
# show first row
print('mean[0]:', mean[0])
print('var[0]:', var[0])
